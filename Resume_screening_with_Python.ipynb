# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyabrat845/Resume-screening-with-Python/blob/main/Resume_screening_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Resume screening with Python**

# %% [markdown]
# Due to the high number of applicants and resumes submissions to job postings, manual resumes screening processes become tedious, ineffective and time consuming for talent acquisition professionals. Therefore, standardized automated screening methods are necessary to categorize qualified from unqualified candidates based on their background, education and professional experience faster, with more efficiency and more accurate results to streamline hiring processes.
#
# So here I have introduced an automated resume screening technique with Python.

# %% [markdown]
# ### **Install libraries**

# %%
pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 77 kB 3.1 MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61100 sha256=eec960238013a95ab601c6cfdbe6479e1992f0a9fe2018628cff3e0b176aff18
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...

# %%
pip install textract
# Out:
# ...
#      |████████████████████████████████| 45 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 13.7 MB/s
# ...
#      |████████████████████████████████| 111 kB 71.1 MB/s
# ...
#      |████████████████████████████████| 103 kB 62.6 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 8.9 MB 25.7 MB/s
# ...
#      |████████████████████████████████| 32.8 MB 36 kB/s
# ...
#      |████████████████████████████████| 73 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 112 kB 47.9 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 26.2 MB/s
# ...
#      |████████████████████████████████| 148 kB 53.8 MB/s
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3982 sha256=5d0611182e25aee6b25b0318d627c5c8a31f4df860c5fe0c28ba9d8721213bdc
#   Stored in directory: /root/.cache/pip/wheels/b7/20/b2/473e3aea9a0c0d3e7b2f7bd81d06d0794fec12752733d1f3a8
# ...

# %%
# Import required libraries
import PyPDF2
import textract
import re
import string
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### **Import data**

# %%
# Open pdf file
resume = open('/content/drive/MyDrive/Almabetter/Priyabrata Mohanty - Software Developer.pdf','rb')

# Read file
pdfReader = PyPDF2.PdfFileReader(resume)

# Get total number of pages
num_pages = pdfReader.numPages

# %%
num_pages
# Out:
# 2

# %%
# Initialize a count for the number of pages
count = 0

# Initialize a text empty etring variable
text = ""

# Extract text from every page on the file
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()

# %%
text
# Out:
# ' \nPriyabrata \nMohanty\n \nContact\n \nAddress:\n \nP\n-\n10, \nPanchasakha Nagar, \nKhandagiri, Bhubaneswar, Odisha\n-\n751030\n \n \nPhone:\n \n+91\n-\n7852964669/8457906264\n \n \nEmail:\n \nPmohanty1998@gmail.com\n \n \nLinkedIn:\n \nlinkedin.com/in/priyabrata\n-\nmohanty\n-\n1b1736169\n \n \nGitHub:\n \ngithub.com/Priyabrat845\n \n \nYouTube:\n \nyoutube.com/channel/UCUCZNqM\nrETahXz1BeyuFKOg\n \nLanguages\n \n\n \nEnglish\n \n\n \nHindi\n \n\n \nOriya\n \n \n \nSummary\n \nEnthusiastic and self\n-\nmotivated \nAssociate System Engineer \nwith proven \ntrack record of understanding and translating technical requir\nements \n.\nWell\n-\nversed in numerous programming languages including \nC\n,\n \nJava, OOP, PL/SQL\n, \nOracle application, Oracle reports and form making, Python\n, \nData science, \nM\nachine learning\n.\n \nSkill Highlights\n \n\n \nSoftware development\n \n\n \nStrong decision maker\n \n\n \nData analysis\n \n\n \nStatistics \n \n\n \nData visualization\n \n\n
# ...

# %% [markdown]
# ### **Data cleaning**

# %%
# Convert all strings to lowercase
text = text.lower()

# Remove numbers
text = re.sub(r'\d+','',text)

# Remove punctuation
text = text.translate(str.maketrans('','',string.punctuation))

# remove unwated characters.
text = text.replace('\n','')

# %%
text
# Out:
# ' priyabrata mohanty contact address p panchasakha nagar khandagiri bhubaneswar odisha  phone   email pmohantygmailcom  linkedin linkedincominpriyabratamohantyb  github githubcompriyabrat  youtube youtubecomchannelucucznqmretahxzbeyufkog languages  english  hindi  oriya   summary enthusiastic and selfmotivated associate system engineer with proven track record of understanding and translating technical requirements wellversed in numerous programming languages including c java oop plsql oracle application oracle reports and form making python data science machine learning skill highlights  software development  strong decision maker  data analysis  statistics   data visualization  ml model buildingdeployment  problem solving  presentation skill experience tata consultancy services bbsrasst system enginee  to present project experience  oracle fusion developer sql plsql  development of bi  otbi reports by fetching data from the user data base  extracting the data of the users from the 
# ...

# %%
type(text)
# Out:
# str

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
plt.rcParams["figure.figsize"] = (10,8)
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.figure(figsize=(5,3))
plt.show()

# %%
# Create dictionary with industrial and system engineering key terms by area
terms = {'Quality/Six Sigma':['black belt','capability analysis','control charts','doe','dmaic','fishbone',
                              'gage r&r', 'green belt','ishikawa','iso','kaizen','kpi','lean','metrics',
                              'pdsa','performance improvement','process improvement','quality',
                              'quality circles','quality tools','root cause','six sigma',
                              'stability analysis','statistical analysis','tqm'],      
        'Operations management':['automation','bottleneck','constraints','cycle time','efficiency','fmea',
                                 'machinery','maintenance','manufacture','line balancing','oee','operations',
                                 'operations research','optimization','overall equipment effectiveness',
                                 'pfmea','process','process mapping','production','resources','safety',
                                 'stoppage','value stream mapping','utilization'],
        'Supply chain':['abc analysis','apics','customer','customs','delivery','distribution','eoq','epq',
                        'fleet','forecast','inventory','logistic','materials','outsourcing','procurement',
                        'reorder point','rout','safety stock','scheduling','shipping','stock','suppliers',
                        'third party logistics','transport','transportation','traffic','supply chain',
                        'vendor','warehouse','wip','work in progress'],
        'Project management':['administration','agile','budget','cost','direction','feasibility analysis',
                              'finance','kanban','leader','leadership','management','milestones','planning',
                              'pmi','pmp','problem','project','risk','schedule','scrum','stakeholders','team member','team player'],
        'Data science':['analytics','api','aws','big data','busines intelligence','clustering','code',
                          'coding','data','database','data mining','data science','deep learning','hadoop',
                          'hypothesis test','iot','internet','machine learning','modeling','nosql','nlp',
                          'predictive','programming','java','python','r','sql','plsql','tableau','text mining','oracle'
                          'visualuzation','data analysis','azure','docker','flask'],
         ''
         
        'Healthcare':['adverse events','care','clinic','cphq','ergonomics','healthcare',
                      'health care','health','hospital','human factors','medical','near misses',
                      'patient','reporting system']}

# %%
# Initializie score counters for each area
quality = 0
operations = 0
supplychain = 0
project = 0
data = 0
healthcare = 0

# Create an empty list where the scores will be stored
scores = []

# Obtain the scores for each area
for area in terms.keys():
        
    if area == 'Quality/Six Sigma':
        for word in terms[area]:
            if word in text:
                quality +=1
                print('Quality/Six Sigma competency:',word)
        scores.append(quality)
        
    elif area == 'Operations management':
        for word in terms[area]:
            if word in text:
                operations +=1
                print('Operations management competency:',word)
        scores.append(operations)
        
    elif area == 'Supply chain':
        for word in terms[area]:
            if word in text:
                supplychain +=1
                print('Supply chain competency:',word)
        scores.append(supplychain)
        
    elif area == 'Project management':
        for word in terms[area]:
            if word in text:
                project +=1
                print('Project management competency:',word)
        scores.append(project)
        
    elif area == 'Data science':
        for word in terms[area]:
            if word in text:
                data +=1
                print('Data science competency:',word)
        scores.append(data)
        
    else:
        for word in terms[area]:
            if word in text:
                healthcare +=1
                print('Healthcare competency:',word)
        scores.append(healthcare)
# Out:
# Quality/Six Sigma competency: lean
# Supply chain competency: customer
# Project management competency: management
# Project management competency: problem
# Project management competency: project
# Data science competency: api
# Data science competency: code
# Data science competency: data
# Data science competency: database
# Data science competency: data science
# Data science competency: deep learning
# Data science competency: iot
# Data science competency: machine learning
# Data science competency: modeling
# Data science competency: programming
# Data science competency: java
# Data science competency: python
# Data science competency: r
# Data science competency: sql
# Data science competency: plsql
# Data science competency: tableau
# Data science competency: data analysis
# Data science competency: azure
# Data science competency: docker
# Data science competency: flask

# %%
# Create a data frame with the scores summary
summary = pd.DataFrame(scores,index=terms.keys(),columns=['score']).sort_values(by='score',ascending=False)
summary
# Out:
#                        score
# Data science              20
# Project management         3
# Quality/Six Sigma          1
# Supply chain               1
# Operations management      0
# Healthcare                 0

# %% [markdown]
# ### **Data visualisation**

# %%
#plt.rcParams["figure.figsize"] = (10,8)
x=['Data science','Project management','Quality/Six Sigma','Supply chain','Operations management','Healthcare']
y=summary['score']
plt.barh(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
# Create pie chart visualization
pie = plt.figure(figsize=(10,8))
plt.pie(summary['score'], labels=summary.index,explode = (0.1,0,0,0,0,0), autopct='%1.0f%%',shadow=True,startangle=90)
#plt.title('Industrial Engineering Candidate - Resume Decomposition by Areas')
plt.axis('equal')
plt.show()

# %% [markdown]
# From this above pie chart we can see that, the sample resume has the more skills sets & experience related to **Data Science** area.

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# The above method can be implemented when we are certain about the skill sets & experience required for a certain job profile.
